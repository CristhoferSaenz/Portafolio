# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(-2,2,0.1)
y = np.array([np.sin(valor * (180/np.pi)) for valor in x ])

# %%
plt.plot(x,y)

plt.show()

# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de Telecomunicaciones</h1> </center>
# <br>
# <center> <h1> </h1> </center>
#
# <center><img src="https://user-images.githubusercontent.com/19308295/115939517-f1c6fe80-a463-11eb-989c-812ab4942586.png" width="380" height="4200"></center>
# <center> <h1>Curso:</h1> </center>
# <center> <h1>Computación 2</h1> </center>
# <br>
# <center> <h2>Docentes:</h2> </center>
# <center> <h2>Ing. Renzo Bolivar</h2> </center>
# <br>
# <center> <h2>Tema:</h2> </center>
# <center> <h1>SERIES TEMPORALES</h1> </center>
# <br>
# <center> <h2>Alumno: </h2> </center>
# <center> <h2>Cristhofer Alexis Saenz Gonzalez</h2> </center>
# <br>
# <br>

# %% [markdown]
# ![linea 2](https://user-images.githubusercontent.com/19308295/115926262-2fb62980-a448-11eb-8189-c2f10e499944.png)

# %% [markdown]
# <center> <h2> <color=#33A5FF> EJERCICIOS </h2> </center>

# %% [markdown]
#  ### Archivo:
# `datos_horarios_contaminacion_lima.csv`

# %% [markdown]
#  ### Investigar Como?

# %% [markdown]
# <div class="well">
# <strong>1.2 - </strong>Visualizar los Datos, utilizar las librerías <code>MatplotLib</code> y <code>Plotly</code>
#
# </div>

# %%
# importar las librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
X = pd.read_csv('datos_horarios_contaminacion_lima.csv')
X
# Out:
#         CODIGO ESTACION       ESTACION   ANO  MES  DIA  HORA   PM 10  PM 2.5  \
# 0                112192            ATE  2010    4    1     0     NaN     NaN
# 1                112192            ATE  2010    4    1     1  135.69     NaN
# 2                112192            ATE  2010    4    1     2  135.84     NaN
# 3                112192            ATE  2010    4    1     3  119.06     NaN
# 4                112192            ATE  2010    4    1     4  104.95     NaN
# ...                 ...            ...   ...  ...  ...   ...     ...     ...
# 703051           111287  PUENTE PIEDRA  2020    9   30    19     NaN     NaN
# 703052           111287  PUENTE PIEDRA  2020    9   30    20     NaN     NaN
# 703053           111287  PUENTE PIEDRA  2020    9   30    21     NaN     NaN
# 703054           111287  PUENTE PIEDRA  2020    9   30    22     NaN     NaN
# 703055           111287  PUENTE PIEDRA  2020    9   30    23     NaN     NaN
#
#          SO2   NO2  O3  CO
# 0       39.8   NaN NaN NaN
# 1       29.9  47.2 NaN NaN
# 2       26.5  44.1 NaN NaN
# 3       25.9  41.4 NaN NaN
# 4       23.3  40.5 NaN NaN
# ...      ...   ...  ..  ..
# 703051   NaN   NaN NaN NaN
# 703052   NaN   NaN NaN NaN
# 703053   NaN   NaN NaN NaN
# 703054   NaN   NaN NaN NaN
# 703055   NaN   NaN NaN NaN
#
# [703056 rows x 12 columns]

# %%
fix, ax = plt.subplots(figsize=(20,5))
X.plot(ax=ax)
plt.show()

# %%
a = X.plot(figsize=(20,5), subplots= True)
plt.show()

# %%
X.columns
# Out:
# Index(['CODIGO ESTACION', 'ESTACION', 'ANO', 'MES', 'DIA', 'HORA', 'PM 10',
#        'PM 2.5', 'SO2', 'NO2', 'O3', 'CO'],
#       dtype='object')

# %%
plt.scatter(X["ANO"],X["SO2"],X["NO2"], alpha = 0.5 ,color = "blue" )
plt.show()

# %%
X.plot.box()
plt.show()

# %% [markdown]
# ![linea 2](https://user-images.githubusercontent.com/19308295/115926262-2fb62980-a448-11eb-8189-c2f10e499944.png)

# %% [markdown]
# ## <font color=#33A5FF>****BIBLIOGRAFÍA****<tfont>

# %% [markdown]
# [1] Pandas TimeStamp https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html
#
# [2] Tutorial Time Series https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/
#
# [3] EDA Time Series https://www.kaggle.com/kanncaa1/time-series-prediction-tutorial-with-eda
#
# [4] Metodo de Interpolación en Pandas https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html
#
# [5] Trabajando con NaN en Pandas https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)

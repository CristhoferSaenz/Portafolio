# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de Telecomunicaciones</h1> </center>
# <br>
# <center> <h1> </h1> </center>
#
# <center><img src="https://user-images.githubusercontent.com/19308295/115939517-f1c6fe80-a463-11eb-989c-812ab4942586.png" width="380" height="4200"></center>
# <center> <h1>Curso:</h1> </center>
# <center> <h1>Computación 2</h1> </center>
# <br>
# <center> <h2>Docentes:</h2> </center>
# <center> <h2>Ing. Renzo Bolivar</h2> </center>
# <br>
# <center> <h2>Tema:</h2> </center>
# <center> <h2>Pandas 2</h2> </center>
# <br>
# <center> <h2>Alumno: </h2> </center>
# <center> <h2>Cristhofer Alexis Saenz Gonzalez</h2> </center>
# <br>
# <br>

# %% [markdown]
# ![linea 2](https://user-images.githubusercontent.com/19308295/115926262-2fb62980-a448-11eb-8189-c2f10e499944.png)

# %% [markdown]
# <center> <h2>Ejercicio 5 </h2> </center>

# %% [markdown]
# <div class="well">Visualizar el <strong>nombre del/(los) estudiante(s) </strong> que no poseen <strong>internet</strong> dato que se puede ubicar en la columna <strong>internet</strong>, desde el archivo <code>student-mat.csv</code> (Carpeta <code>data_ejercicios </code> ) debera visualizar por pantalla <strong>todos los datos de dicho(s) alumno(s)</strong> y adicionalmente guardar la información en el archivo <code>student-internet.csv</code>.
#
#
# </div>

# %%
import numpy as np
import pandas as pd

# %%
x = pd.read_csv("data_ejercicios/student-mat.csv",index_col='sex')
x
# Out:
#     school  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# sex
# F       GP   18       U     GT3       A     4     4   at_home   teacher
# F       GP   17       U     GT3       T     1     1   at_home     other
# F       GP   15       U     LE3       T     1     1   at_home     other
# F       GP   15       U     GT3       T     4     2    health  services
# F       GP   16       U     GT3       T     3     3     other     other
# ..     ...  ...     ...     ...     ...   ...   ...       ...       ...
# M       MS   20       U     LE3       A     2     2  services  services
# M       MS   17       U     LE3       T     3     1  services  services
# M       MS   21       R     GT3       T     1     1     other     other
# M       MS   18       R     LE3       T     3     2  services     other
# M       MS   19       U     LE3       T     1     1     other   at_home
#
#      reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  \
# sex          ...
# ...

# %%
#No exite la comlumna de nombres
x.columns
# Out:
# Index(['school', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
inter = x.sort_values('internet', ascending = False)

inter
# Out:
#     school  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# sex
# M       GP   16       R     LE3       T     3     3   teacher     other
# M       GP   16       U     GT3       T     4     4    health     other
# M       GP   17       U     LE3       T     1     1    health     other
# M       GP   17       R     GT3       T     2     1     other     other
# M       GP   18       U     GT3       T     2     1  services  services
# ..     ...  ...     ...     ...     ...   ...   ...       ...       ...
# F       GP   17       R     LE3       T     4     4  services     other
# F       GP   15       R     GT3       T     2     2   at_home     other
# M       GP   16       R     GT3       T     2     1     other     other
# F       GP   17       U     GT3       T     2     3   at_home     other
# F       GP   18       U     GT3       A     4     4   at_home   teacher
#
#          reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  \
# ...

# %%
inter.to_csv('data_ejercicios/student-internet.csv')

# %% [markdown]
# ![linea 2](https://user-images.githubusercontent.com/19308295/115926262-2fb62980-a448-11eb-8189-c2f10e499944.png)

# %% [markdown]
# ## <font color=greenblack>****BIBLIOGRAFÍA****<tfont>

# %% [markdown]
# [1] Guía de pandas oficial https://pandas.pydata.org/docs/user_guide/index.html
#
# [2] Python Pandas Tutorial: A Complete Introduction for Beginners https://bit.ly/2AQMQld
#
# [3] Guía para pandas https://pybonacci.org/2014/05/30/pandas-i/

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)
